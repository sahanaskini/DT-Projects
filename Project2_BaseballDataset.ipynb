# %%
# Mounting the Google Colab Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
#Importing the Baseball data set and Rename the Column Values
baseball=pd.read_csv('/content/drive/My Drive/DS Datasets/DT Project Datasets/baseball.csv', names = ['Wins' , 'Runs' , 'At Bats' , 'Hits' , 'Doubles' , 'Triples' , 'Homeruns' , 'BB' , 'Strikeouts' ,'Stolen Bases' , 'Runs Allowed', 'Earned Runs' , 'Earned Run Average' , 'CG' , 'Shutouts' , 'Saves' , 'Errors'])
baseball
# Out:
#    Wins Runs At Bats  Hits Doubles  ... Earned Run Average  CG Shutouts Saves Errors
# 0     W    R      AB     H      2B  ...                ERA  CG      SHO    SV      E
# 1    95  724    5575  1497     300  ...               3.73   2        8    56     88
# 2    83  696    5467  1349     277  ...               4.07   2       12    45     86
# 3    81  669    5439  1395     303  ...               3.67  11       10    38     79
# 4    76  622    5533  1381     260  ...               3.98   7        9    37    101
# 5    74  689    5605  1515     289  ...               4.64   7       12    35     86
# 6    93  891    5509  1480     308  ...                3.8   7       10    34     88
# 7    87  764    5567  1397     272  ...               4.03   3        4    48     93
# 8    81  713    5485  1370     246  ...               4.05   0       10    43     77
# 9    80  644    5485  1383     278  ...               3.74   1       12    60     95
# ...

# %%
len(baseball)
# Out:
# 31

# %% [markdown]
# Size of the dataset:

# %%
# Check basics about baseball dataset
print(baseball.shape)
# Out:
# (31, 17)

# %%
#Drop unnecessary Column Values
baseball = baseball.drop(['BB' , 'CG'], axis =1)
baseball
# Out:
#    Wins Runs At Bats  Hits  ... Earned Run Average Shutouts Saves Errors
# 0     W    R      AB     H  ...                ERA      SHO    SV      E
# 1    95  724    5575  1497  ...               3.73        8    56     88
# 2    83  696    5467  1349  ...               4.07       12    45     86
# 3    81  669    5439  1395  ...               3.67       10    38     79
# 4    76  622    5533  1381  ...               3.98        9    37    101
# 5    74  689    5605  1515  ...               4.64       12    35     86
# 6    93  891    5509  1480  ...                3.8       10    34     88
# 7    87  764    5567  1397  ...               4.03        4    48     93
# 8    81  713    5485  1370  ...               4.05       10    43     77
# 9    80  644    5485  1383  ...               3.74       12    60     95
# 10   78  748    5640  1495  ...               4.31       10    40     97
# 11   88  751    5511  1419  ...               4.24        9    45    119
# ...

# %%
baseball.head
# Out:
# <bound method NDFrame.head of    Wins Runs At Bats  Hits  ... Earned Run Average Shutouts Saves Errors
# 0     W    R      AB     H  ...                ERA      SHO    SV      E
# 1    95  724    5575  1497  ...               3.73        8    56     88
# 2    83  696    5467  1349  ...               4.07       12    45     86
# 3    81  669    5439  1395  ...               3.67       10    38     79
# 4    76  622    5533  1381  ...               3.98        9    37    101
# 5    74  689    5605  1515  ...               4.64       12    35     86
# 6    93  891    5509  1480  ...                3.8       10    34     88
# 7    87  764    5567  1397  ...               4.03        4    48     93
# 8    81  713    5485  1370  ...               4.05       10    43     77
# 9    80  644    5485  1383  ...               3.74       12    60     95
# 10   78  748    5640  1495  ...               4.31       10    40     97
# ...

# %% [markdown]
# Statistical Summary of Numeric Variables:

# %%
baseball.describe()
# Out:
#        Wins Runs At Bats  Hits  ... Earned Run Average Shutouts Saves Errors
# count    31   31      31    31  ...                 31       31    31     31
# unique   25   29      30    30  ...                 31       13    21     22
# top      68  696    5485  1363  ...               3.62       12    35     86
# freq      3    2       2     2  ...                  1        7     4      3
#
# [4 rows x 15 columns]

# %% [markdown]
# Identification of data types:

# %%
baseball.dtypes
# Out:
# Wins                  object
# Runs                  object
# At Bats               object
# Hits                  object
# Doubles               object
# Triples               object
# Homeruns              object
# Strikeouts            object
# Stolen Bases          object
# Runs Allowed          object
# Earned Runs           object
# Earned Run Average    object
# Shutouts              object
# Saves                 object
# Errors                object
# dtype: object

# %%
baseball.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Wins                31 non-null     object
#  1   Runs                31 non-null     object
#  2   At Bats             31 non-null     object
#  3   Hits                31 non-null     object
#  4   Doubles             31 non-null     object
#  5   Triples             31 non-null     object
#  6   Homeruns            31 non-null     object
#  7   Strikeouts          31 non-null     object
#  8   Stolen Bases        31 non-null     object
#  9   Runs Allowed        31 non-null     object
#  10  Earned Runs         31 non-null     object
#  11  Earned Run Average  31 non-null     object
#  12  Shutouts            31 non-null     object
#  13  Saves               31 non-null     object
#  14  Errors              31 non-null     object
# dtypes: object(15)
# ...

# %% [markdown]
# Non-Graphical Univariate Analysis:

# %%
baseball['Wins'].value_counts()
# Out:
# 68     3
# 83     2
# 74     2
# 81     2
# 76     2
# 87     1
# 79     1
# 64     1
# 93     1
# 67     1
# 86     1
# 90     1
# 78     1
# 100    1
# 88     1
# W      1
# 80     1
# 92     1
# 95     1
# 97     1
# 98     1
# 84     1
# 63     1
# 85     1
# 71     1
# Name: Wins, dtype: int64

# %% [markdown]
# Finding null values:

# %%
print(baseball.isnull().sum(axis = 0))

#axis=0: checks for null values on all rows for each column
#axis=1: checks for null values on all columns for each row
# Out:
# Wins                  0
# Runs                  0
# At Bats               0
# Hits                  0
# Doubles               0
# Triples               0
# Homeruns              0
# Strikeouts            0
# Stolen Bases          0
# Runs Allowed          0
# Earned Runs           0
# Earned Run Average    0
# Shutouts              0
# Saves                 0
# Errors                0
# dtype: int64

# %% [markdown]
# Graphical Univariate Analysis:

# %%
#Exploring and visualizing the data: Applying EDA **histogram**

plt.hist(baseball['Wins'])
plt.xlabel('Team Wins')
plt.title('Histogram Plot of Total Wins')
# Out:
# Text(0.5, 1.0, 'Histogram Plot of Total Wins')

# %%
#Exploring and visualizing the data: Applying EDA **Scatter Plot**
plt.scatter(baseball['Runs'],baseball['At Bats'])
plt.title('Runs per At Bat')
plt.xlabel('Runs')
plt.ylabel('At Bat')
# Out:
# Text(0, 0.5, 'At Bat')

# %%
#Countplot
sns.countplot(baseball.Runs)

# %%
#checking for the presence of values using heatmap
sns.heatmap(baseball.isnull(), annot= True)
plt.show()

# %%
#Checking the skewness of Avocado Dataset

baseball.skew()
# Out:
# Series([], dtype: float64)

# %%
#using label encoding and one-hot encoding

from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
baseball['Runs'] = le.fit_transform(baseball['Runs'])
baseball['Wins'] = le.fit_transform(baseball['Wins'])
baseball.head(5)
# Out:
#    Wins  Runs At Bats  Hits  ... Earned Run Average Shutouts Saves Errors
# 0    24    28      AB     H  ...                ERA      SHO    SV      E
# 1    21    21    5575  1497  ...               3.73        8    56     88
# 2    12    16    5467  1349  ...               4.07       12    45     86
# 3    11    12    5439  1395  ...               3.67       10    38     79
# 4     7     2    5533  1381  ...               3.98        9    37    101
#
# [5 rows x 15 columns]

# %%
#dummifying data required for spliting the data

baseball = pd.get_dummies(baseball)
baseball.head(5)
# Out:
#    Wins  Runs  At Bats_5385  ...  Errors_96  Errors_97  Errors_E
# 0    24    28             0  ...          0          0         1
# 1    21    21             0  ...          0          0         0
# 2    12    16             0  ...          0          0         0
# 3    11    12             0  ...          0          0         0
# 4     7     2             0  ...          0          0         0
#
# [5 rows x 344 columns]

# %%
baseball.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Columns: 344 entries, Wins to Errors_E
# dtypes: int64(2), uint8(342)
# memory usage: 11.0 KB

# %%
#spliting the data

from sklearn.model_selection import train_test_split

y = baseball['Wins']
X = baseball

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.25, random_state=0)

# %%
#Using Decision Tree Model

from sklearn.metrics import classification_report
from sklearn.tree import DecisionTreeClassifier

dtree = DecisionTreeClassifier(random_state=1)
dtree.fit(X_train, y_train)
y_pred1 = dtree.predict(X_test)
print(classification_report(y_test, y_pred1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       0.0
#            1       0.00      0.00      0.00       1.0
#            6       0.00      0.00      0.00       1.0
#            7       0.00      0.00      0.00       0.0
#            8       0.00      0.00      0.00       1.0
#           11       0.00      0.00      0.00       0.0
#           12       0.00      0.00      0.00       2.0
#           13       0.00      0.00      0.00       1.0
#           14       0.00      0.00      0.00       1.0
#           17       0.00      0.00      0.00       1.0
#           24       0.00      0.00      0.00       0.0
#
#     accuracy                           0.00       8.0
#    macro avg       0.00      0.00      0.00       8.0
# weighted avg       0.00      0.00      0.00       8.0

# %%
#Applying Random Forest Model

from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(random_state=1)
rf.fit(X_train, y_train)
y_pred2 = rf.predict(X_test)
print(classification_report(y_test, y_pred2))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00       1.0
#            4       0.00      0.00      0.00       0.0
#            6       0.00      0.00      0.00       1.0
#            7       0.00      0.00      0.00       0.0
#            8       0.00      0.00      0.00       1.0
#           12       0.00      0.00      0.00       2.0
#           13       0.00      0.00      0.00       1.0
#           14       0.00      0.00      0.00       1.0
#           17       0.00      0.00      0.00       1.0
#
#     accuracy                           0.00       8.0
#    macro avg       0.00      0.00      0.00       8.0
# weighted avg       0.00      0.00      0.00       8.0

# %%
#Applying Lasso Regression

from sklearn.linear_model import Lasso
from sklearn.metrics import mean_squared_error
from math import sqrt
from sklearn.metrics import r2_score

model_lasso = Lasso(alpha=0.01)
model_lasso.fit(X_train, y_train) 
pred_train_lasso= model_lasso.predict(X_train)
print(np.sqrt(mean_squared_error(y_train,pred_train_lasso)))
print(r2_score(y_train, pred_train_lasso))

pred_test_lasso= model_lasso.predict(X_test)
print(np.sqrt(mean_squared_error(y_test,pred_test_lasso))) 
print(r2_score(y_test, pred_test_lasso))
# Out:
# 0.0013419350805281068
# 0.9999999675715624
# 0.0008763162840352415
# 0.9999999662216257
