# %%
# Mounting the Google Colab Drive

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
#Importing the HR Analytics data set

hr=pd.read_csv('/content/drive/My Drive/DS Datasets/DT Project Datasets/HR Analytics.csv')
hr
# Out:
#       Age Attrition  ... YearsSinceLastPromotion  YearsWithCurrManager
# 0      41       Yes  ...                       0                     5
# 1      49        No  ...                       1                     7
# 2      37       Yes  ...                       0                     0
# 3      33        No  ...                       3                     0
# 4      27        No  ...                       2                     2
# ...   ...       ...  ...                     ...                   ...
# 1465   36        No  ...                       0                     3
# 1466   39        No  ...                       1                     7
# 1467   27        No  ...                       0                     3
# 1468   49        No  ...                       0                     8
# 1469   34        No  ...                       1                     2
#
# [1470 rows x 35 columns]

# %%
hr.shape
# Out:
# (1470, 35)

# %%
hr.head
# Out:
# <bound method NDFrame.head of       Age Attrition  ... YearsSinceLastPromotion  YearsWithCurrManager
# 0      41       Yes  ...                       0                     5
# 1      49        No  ...                       1                     7
# 2      37       Yes  ...                       0                     0
# 3      33        No  ...                       3                     0
# 4      27        No  ...                       2                     2
# ...   ...       ...  ...                     ...                   ...
# 1465   36        No  ...                       0                     3
# 1466   39        No  ...                       1                     7
# 1467   27        No  ...                       0                     3
# 1468   49        No  ...                       0                     8
# 1469   34        No  ...                       1                     2
#
# [1470 rows x 35 columns]>

# %%
hr.describe
# Out:
# <bound method NDFrame.describe of       Age Attrition  ... YearsSinceLastPromotion  YearsWithCurrManager
# 0      41       Yes  ...                       0                     5
# 1      49        No  ...                       1                     7
# 2      37       Yes  ...                       0                     0
# 3      33        No  ...                       3                     0
# 4      27        No  ...                       2                     2
# ...   ...       ...  ...                     ...                   ...
# 1465   36        No  ...                       0                     3
# 1466   39        No  ...                       1                     7
# 1467   27        No  ...                       0                     3
# 1468   49        No  ...                       0                     8
# 1469   34        No  ...                       1                     2
#
# [1470 rows x 35 columns]>

# %%
hr.info
# Out:
# <bound method DataFrame.info of       Age Attrition  ... YearsSinceLastPromotion  YearsWithCurrManager
# 0      41       Yes  ...                       0                     5
# 1      49        No  ...                       1                     7
# 2      37       Yes  ...                       0                     0
# 3      33        No  ...                       3                     0
# 4      27        No  ...                       2                     2
# ...   ...       ...  ...                     ...                   ...
# 1465   36        No  ...                       0                     3
# 1466   39        No  ...                       1                     7
# 1467   27        No  ...                       0                     3
# 1468   49        No  ...                       0                     8
# 1469   34        No  ...                       1                     2
#
# [1470 rows x 35 columns]>

# %%
#checking for null values

print(hr.isnull().sum(axis = 0))
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
#Exploring and visualizing the data: Applying EDA **Bar Graph**

print(hr.Attrition.value_counts(normalize=True))
at = (hr.Attrition.value_counts())
at
# Out:
# No     0.838776
# Yes    0.161224
# Name: Attrition, dtype: float64
# No     1233
# Yes     237
# Name: Attrition, dtype: int64

# %%
at.plot(kind = 'bar', color=('b','g'))
plt.title('Attrition')
# Out:
# Text(0.5, 1.0, 'Attrition')

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.bar(hr['EmployeeNumber'],hr['JobSatisfaction'], color = 'b')
plt.title('Bar Graph Plotting EmployeeNumber to JobSatisfaction')
plt.show()

# %%
#Calculate Average Hourly Hours

print('Mean:', hr.HourlyRate.mean())
print('Standard Deviation:', np.std(hr.HourlyRate))
# Out:
# Mean: 65.89115646258503
# Standard Deviation: 20.322511646324006

# %%
#Calculate teh Mean and Standard Deviation of Attrition 'Yes'

print('Mean of Attrition==Yes', hr[hr.Attrition=='Yes']['HourlyRate'].mean())
print('SD of Attrition==Yes', np.std(hr[hr.Attrition=='Yes']['HourlyRate']))
# Out:
# Mean of Attrition==Yes 65.57383966244726
# SD of Attrition==Yes 20.057507807158082

# %%
#Check if Overtime leads to Attrition

at = (hr.Attrition.value_counts())
ot = (hr.OverTime.value_counts())

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.bar(at, ot, color = ('b','g'), width =50)
plt.title('Overtime v/s Attrition')
plt.show()

# %%
#Check JobRole of each Employee in every Department
for dt in hr['Department'].unique():
    print('\n', dt, ':')
    print(hr[hr['Department']==dt]['JobRole'].value_counts())
# Out:
#  Sales :
# Sales Executive         326
# Sales Representative     83
# Manager                  37
# Name: JobRole, dtype: int64
#
#  Research & Development :
# Research Scientist           292
# Laboratory Technician        259
# Manufacturing Director       145
# Healthcare Representative    131
# Research Director             80
# Manager                       54
# Name: JobRole, dtype: int64
#
#  Human Resources :
# Human Resources    52
# Manager            11
# Name: JobRole, dtype: int64

# %%
#Check for Correation of Variables

corr = hr.corr()
plt.subplots(figsize=(15,10))
sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns, annot=True, cmap=sns.diverging_palette(220, 20, as_cmap=True))

# %%
#Checking the skewness of Avocado Dataset

hr.skew()
# Out:
# Age                         0.413286
# DailyRate                  -0.003519
# DistanceFromHome            0.958118
# Education                  -0.289681
# EmployeeCount               0.000000
# EmployeeNumber              0.016574
# EnvironmentSatisfaction    -0.321654
# HourlyRate                 -0.032311
# JobInvolvement             -0.498419
# JobLevel                    1.025401
# JobSatisfaction            -0.329672
# MonthlyIncome               1.369817
# MonthlyRate                 0.018578
# NumCompaniesWorked          1.026471
# PercentSalaryHike           0.821128
# PerformanceRating           1.921883
# RelationshipSatisfaction   -0.302828
# StandardHours               0.000000
# StockOptionLevel            0.968980
# TotalWorkingYears           1.117172
# TrainingTimesLastYear       0.553124
# WorkLifeBalance            -0.552480
# YearsAtCompany              1.764529
# YearsInCurrentRole          0.917363
# YearsSinceLastPromotion     1.984290
# ...

# %%
#using label encoding and one-hot encoding

from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
hr['Attrition'] = le.fit_transform(hr['Attrition'])
hr['OverTime'] = le.fit_transform(hr['OverTime'])
hr.head(5)
# Out:
#    Age  Attrition  ... YearsSinceLastPromotion  YearsWithCurrManager
# 0   41          1  ...                       0                     5
# 1   49          0  ...                       1                     7
# 2   37          1  ...                       0                     0
# 3   33          0  ...                       3                     0
# 4   27          0  ...                       2                     2
#
# [5 rows x 35 columns]

# %%
#dummifying data required for spliting the data

hr = pd.get_dummies(hr)
hr.head(5)
# Out:
#    Age  Attrition  ...  MaritalStatus_Single  Over18_Y
# 0   41          1  ...                     1         1
# 1   49          0  ...                     0         1
# 2   37          1  ...                     1         1
# 3   33          0  ...                     0         1
# 4   27          0  ...                     0         1
#
# [5 rows x 55 columns]

# %%
from sklearn.ensemble import RandomForestClassifier
SEED = 42
# define feature X and target y dataset
X, y = hr.drop('Attrition', axis=1), hr['Attrition']

# use RandomForestClassifier
n = 10    # top n features
r = RandomForestClassifier(random_state=SEED, n_estimators=200, max_depth=3)
r_model = r.fit(X, y)
pd.Series(r_model.feature_importances_, index=X.columns).nlargest(n).plot(kind='barh', 
    figsize=[8, n/3], color='navy').invert_yaxis()    # Plot in descending order
ticks_x = np.linspace(0, 0.2, 5)   # (start, end, number of ticks)
plt.xticks(ticks_x, fontsize=15, color='black')
plt.yticks(size=15, color='pink' )
plt.title('Plot by RandomForestClassifier', family='fantasy', size=15)
top10_features = pd.Series(r_model.feature_importances_, index=X.columns).nlargest(10)
print('Top 10 Features:', list(top10_features.index))

# check for correlation between top 10 features
X = hr.loc[:, top10_features.index]
y = hr['Attrition']
hr_top10 = X.join(y)
# correlation matrix heatmap visualization
sns.set(style="white")
# Generate a mask for the upper triangle
mask = np.zeros_like(hr_top10.corr(), dtype=np.bool)
mask[np.triu_indices_from(mask)] = True
# Set up the matplotlib figure to control size of heatmap
fig, ax = plt.subplots(figsize=(9,9))
# Create a custom color palette
cmap = sns.diverging_palette(255, 10, as_cmap=True)  # as_cmap returns a matplotlib colormap object rather than a list of colors
# Red=10, Green=128, Blue=255
# Plot the heatmap
sns.heatmap(hr_top10.corr().round(2), mask=mask, annot=True, annot_kws={"size": 12}, square=True, 
            cmap=cmap , vmin=-1, vmax=1, ax=ax)  # annot=True display corr label
# Prevent Heatmap Cut-Off Issue
bottom, top = ax.get_ylim()
ax.set_ylim(bottom+0.5, top-0.5)
# Out:
# Top 10 Features: ['OverTime', 'MonthlyIncome', 'TotalWorkingYears', 'JobLevel', 'Age', 'YearsAtCompany', 'YearsWithCurrManager', 'StockOptionLevel', 'MaritalStatus_Single', 'YearsInCurrentRole']
# (11.5, -0.5)

# %%
#spliting the data

from sklearn.model_selection import train_test_split

y = hr['Attrition']
X = hr

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.25, random_state=0)

# %%
#Applying Lasso Regression

from sklearn.linear_model import Lasso
from sklearn.metrics import mean_squared_error
from math import sqrt
from sklearn.metrics import r2_score

model_lasso = Lasso(alpha=0.01)
model_lasso.fit(X_train, y_train) 
pred_train_lasso= model_lasso.predict(X_train)
print(np.sqrt(mean_squared_error(y_train,pred_train_lasso)))
print(r2_score(y_train, pred_train_lasso))

pred_test_lasso= model_lasso.predict(X_test)
print(np.sqrt(mean_squared_error(y_test,pred_test_lasso))) 
print(r2_score(y_test, pred_test_lasso))
# Out:
# 0.02760972675047034
# 0.9943968445158028
# 0.027518224951634356
# 0.9942964299080821
